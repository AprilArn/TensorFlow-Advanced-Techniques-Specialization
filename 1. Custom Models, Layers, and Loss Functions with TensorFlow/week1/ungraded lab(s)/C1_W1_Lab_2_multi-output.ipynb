# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 257.9988 - y1_output_loss: 121.7483 - y2_output_loss: 134.2297 - y1_output_root_mean_squared_error: 11.0842 - y2_output_root_mean_squared_error: 11.6249 - val_loss: 45.8548 - val_y1_output_loss: 18.4686 - val_y2_output_loss: 26.9794 - val_y1_output_root_mean_squared_error: 4.3436 - val_y2_output_root_mean_squared_error: 5.1950
# Epoch 2/500
# 614/614 [==============================] - 0s 166us/sample - loss: 35.3957 - y1_output_loss: 13.5222 - y2_output_loss: 21.6338 - y1_output_root_mean_squared_error: 3.6906 - y2_output_root_mean_squared_error: 4.6664 - val_loss: 27.1661 - val_y1_output_loss: 10.7532 - val_y2_output_loss: 15.5684 - val_y1_output_root_mean_squared_error: 3.3402 - val_y2_output_root_mean_squared_error: 4.0012
# Epoch 3/500
# 614/614 [==============================] - 0s 172us/sample - loss: 27.1535 - y1_output_loss: 10.7914 - y2_output_loss: 16.2540 - y1_output_root_mean_squared_error: 3.2920 - y2_output_root_mean_squared_error: 4.0393 - val_loss: 25.8348 - val_y1_output_loss: 10.1882 - val_y2_output_loss: 15.1260 - val_y1_output_root_mean_squared_error: 3.2427 - val_y2_output_root_mean_squared_error: 3.9140
# Epoch 4/500
# 614/614 [==============================] - 0s 187us/sample - loss: 28.3156 - y1_output_loss: 10.7492 - y2_output_loss: 17.4041 - y1_output_root_mean_squared_error: 3.2825 - y2_output_root_mean_squared_error: 4.1882 - val_loss: 30.4546 - val_y1_output_loss: 10.1832 - val_y2_output_loss: 19.2775 - val_y1_output_root_mean_squared_error: 3.2446 - val_y2_output_root_mean_squared_error: 4.4640
# Epoch 5/500
# 614/614 [==============================] - 0s 164us/sample - loss: 22.3473 - y1_output_loss: 9.4638 - y2_output_loss: 13.0016 - y1_output_root_mean_squared_error: 3.0670 - y2_output_root_mean_squared_error: 3.5973 - val_loss: 22.0307 - val_y1_output_loss: 8.2379 - val_y2_output_loss: 13.3276 - val_y1_output_root_mean_squared_error: 2.9143 - val_y2_output_root_mean_squared_error: 3.6794
# Epoch 6/500
# 614/614 [==============================] - 0s 154us/sample - loss: 22.5118 - y1_output_loss: 8.8933 - y2_output_loss: 13.4129 - y1_output_root_mean_squared_error: 2.9967 - y2_output_root_mean_squared_error: 3.6785 - val_loss: 23.2259 - val_y1_output_loss: 8.3858 - val_y2_output_loss: 14.0790 - val_y1_output_root_mean_squared_error: 2.9455 - val_y2_output_root_mean_squared_error: 3.8144
# Epoch 7/500
# 614/614 [==============================] - 0s 149us/sample - loss: 21.0904 - y1_output_loss: 8.9176 - y2_output_loss: 12.0312 - y1_output_root_mean_squared_error: 2.9944 - y2_output_root_mean_squared_error: 3.4820 - val_loss: 23.0658 - val_y1_output_loss: 8.7046 - val_y2_output_loss: 13.5353 - val_y1_output_root_mean_squared_error: 3.0059 - val_y2_output_root_mean_squared_error: 3.7457
# Epoch 8/500
# 614/614 [==============================] - 0s 148us/sample - loss: 19.5893 - y1_output_loss: 8.1741 - y2_output_loss: 11.3672 - y1_output_root_mean_squared_error: 2.8656 - y2_output_root_mean_squared_error: 3.3731 - val_loss: 20.7299 - val_y1_output_loss: 7.2359 - val_y2_output_loss: 12.8475 - val_y1_output_root_mean_squared_error: 2.7356 - val_y2_output_root_mean_squared_error: 3.6396
# Epoch 9/500
# 614/614 [==============================] - 0s 167us/sample - loss: 20.7948 - y1_output_loss: 8.6829 - y2_output_loss: 11.9664 - y1_output_root_mean_squared_error: 2.9580 - y2_output_root_mean_squared_error: 3.4706 - val_loss: 21.6445 - val_y1_output_loss: 7.5730 - val_y2_output_loss: 13.3401 - val_y1_output_root_mean_squared_error: 2.8027 - val_y2_output_root_mean_squared_error: 3.7134
# Epoch 10/500
# 614/614 [==============================] - 0s 156us/sample - loss: 20.9468 - y1_output_loss: 8.7719 - y2_output_loss: 12.3836 - y1_output_root_mean_squared_error: 2.9461 - y2_output_root_mean_squared_error: 3.5025 - val_loss: 28.5722 - val_y1_output_loss: 9.0368 - val_y2_output_loss: 18.7723 - val_y1_output_root_mean_squared_error: 3.0457 - val_y2_output_root_mean_squared_error: 4.3927
# Epoch 11/500
# 614/614 [==============================] - 0s 154us/sample - loss: 18.9731 - y1_output_loss: 8.1613 - y2_output_loss: 10.7031 - y1_output_root_mean_squared_error: 2.8667 - y2_output_root_mean_squared_error: 3.2795 - val_loss: 22.7285 - val_y1_output_loss: 7.4748 - val_y2_output_loss: 14.6796 - val_y1_output_root_mean_squared_error: 2.7687 - val_y2_output_root_mean_squared_error: 3.8811
# Epoch 12/500
# 614/614 [==============================] - 0s 149us/sample - loss: 22.9249 - y1_output_loss: 9.1071 - y2_output_loss: 14.0830 - y1_output_root_mean_squared_error: 2.9869 - y2_output_root_mean_squared_error: 3.7421 - val_loss: 87.4887 - val_y1_output_loss: 25.8394 - val_y2_output_loss: 60.2723 - val_y1_output_root_mean_squared_error: 5.1485 - val_y2_output_root_mean_squared_error: 7.8091
# Epoch 13/500
# 614/614 [==============================] - 0s 164us/sample - loss: 22.2998 - y1_output_loss: 8.1073 - y2_output_loss: 14.0767 - y1_output_root_mean_squared_error: 2.8608 - y2_output_root_mean_squared_error: 3.7571 - val_loss: 21.1149 - val_y1_output_loss: 6.5543 - val_y2_output_loss: 13.8081 - val_y1_output_root_mean_squared_error: 2.6060 - val_y2_output_root_mean_squared_error: 3.7846
# Epoch 14/500
# 614/614 [==============================] - 0s 148us/sample - loss: 22.7225 - y1_output_loss: 8.7031 - y2_output_loss: 14.2522 - y1_output_root_mean_squared_error: 2.9415 - y2_output_root_mean_squared_error: 3.7510 - val_loss: 20.1019 - val_y1_output_loss: 6.8226 - val_y2_output_loss: 12.7887 - val_y1_output_root_mean_squared_error: 2.6593 - val_y2_output_root_mean_squared_error: 3.6097
# Epoch 15/500
# 614/614 [==============================] - 0s 178us/sample - loss: 20.1017 - y1_output_loss: 8.1533 - y2_output_loss: 12.3621 - y1_output_root_mean_squared_error: 2.8145 - y2_output_root_mean_squared_error: 3.4900 - val_loss: 74.5874 - val_y1_output_loss: 18.1596 - val_y2_output_loss: 54.4784 - val_y1_output_root_mean_squared_error: 4.3115 - val_y2_output_root_mean_squared_error: 7.4832
# Epoch 16/500
# 614/614 [==============================] - 0s 157us/sample - loss: 19.0256 - y1_output_loss: 7.6870 - y2_output_loss: 11.4034 - y1_output_root_mean_squared_error: 2.7582 - y2_output_root_mean_squared_error: 3.3790 - val_loss: 17.2348 - val_y1_output_loss: 6.1758 - val_y2_output_loss: 10.6627 - val_y1_output_root_mean_squared_error: 2.5192 - val_y2_output_root_mean_squared_error: 3.2997
# Epoch 17/500
# 614/614 [==============================] - 0s 150us/sample - loss: 16.7189 - y1_output_loss: 7.1547 - y2_output_loss: 9.6518 - y1_output_root_mean_squared_error: 2.6617 - y2_output_root_mean_squared_error: 3.1039 - val_loss: 16.4190 - val_y1_output_loss: 5.6150 - val_y2_output_loss: 10.5055 - val_y1_output_root_mean_squared_error: 2.4080 - val_y2_output_root_mean_squared_error: 3.2589
# Epoch 18/500
# 614/614 [==============================] - 0s 148us/sample - loss: 18.9312 - y1_output_loss: 7.5887 - y2_output_loss: 11.2379 - y1_output_root_mean_squared_error: 2.7604 - y2_output_root_mean_squared_error: 3.3633 - val_loss: 34.8138 - val_y1_output_loss: 8.9517 - val_y2_output_loss: 25.7678 - val_y1_output_root_mean_squared_error: 3.0194 - val_y2_output_root_mean_squared_error: 5.0692
# Epoch 19/500
# 614/614 [==============================] - 0s 156us/sample - loss: 18.5976 - y1_output_loss: 7.1780 - y2_output_loss: 11.4617 - y1_output_root_mean_squared_error: 2.6830 - y2_output_root_mean_squared_error: 3.3763 - val_loss: 29.5270 - val_y1_output_loss: 8.7881 - val_y2_output_loss: 20.4758 - val_y1_output_root_mean_squared_error: 2.9931 - val_y2_output_root_mean_squared_error: 4.5353
# Epoch 20/500
# 614/614 [==============================] - 0s 153us/sample - loss: 18.0903 - y1_output_loss: 6.8173 - y2_output_loss: 11.2150 - y1_output_root_mean_squared_error: 2.6090 - y2_output_root_mean_squared_error: 3.3591 - val_loss: 23.8173 - val_y1_output_loss: 7.0490 - val_y2_output_loss: 16.0196 - val_y1_output_root_mean_squared_error: 2.6949 - val_y2_output_root_mean_squared_error: 4.0688
# Epoch 21/500
# 614/614 [==============================] - 0s 186us/sample - loss: 15.7951 - y1_output_loss: 6.3139 - y2_output_loss: 9.5437 - y1_output_root_mean_squared_error: 2.5052 - y2_output_root_mean_squared_error: 3.0853 - val_loss: 29.0873 - val_y1_output_loss: 6.7127 - val_y2_output_loss: 21.5980 - val_y1_output_root_mean_squared_error: 2.6161 - val_y2_output_root_mean_squared_error: 4.7163
# Epoch 22/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.6878 - y1_output_loss: 5.8527 - y2_output_loss: 8.7467 - y1_output_root_mean_squared_error: 2.4278 - y2_output_root_mean_squared_error: 2.9654 - val_loss: 17.4939 - val_y1_output_loss: 5.5091 - val_y2_output_loss: 11.5325 - val_y1_output_root_mean_squared_error: 2.3786 - val_y2_output_root_mean_squared_error: 3.4404
# Epoch 23/500
# 614/614 [==============================] - 0s 150us/sample - loss: 15.5123 - y1_output_loss: 6.0947 - y2_output_loss: 9.4142 - y1_output_root_mean_squared_error: 2.4726 - y2_output_root_mean_squared_error: 3.0657 - val_loss: 25.7718 - val_y1_output_loss: 5.8637 - val_y2_output_loss: 20.0003 - val_y1_output_root_mean_squared_error: 2.4427 - val_y2_output_root_mean_squared_error: 4.4503
# Epoch 24/500
# 614/614 [==============================] - 0s 153us/sample - loss: 13.5019 - y1_output_loss: 5.7474 - y2_output_loss: 7.6362 - y1_output_root_mean_squared_error: 2.4074 - y2_output_root_mean_squared_error: 2.7761 - val_loss: 13.7148 - val_y1_output_loss: 4.4717 - val_y2_output_loss: 8.8969 - val_y1_output_root_mean_squared_error: 2.1407 - val_y2_output_root_mean_squared_error: 3.0219
# Epoch 25/500
# 614/614 [==============================] - 0s 156us/sample - loss: 13.2551 - y1_output_loss: 5.2326 - y2_output_loss: 7.9655 - y1_output_root_mean_squared_error: 2.2947 - y2_output_root_mean_squared_error: 2.8265 - val_loss: 19.9408 - val_y1_output_loss: 5.0333 - val_y2_output_loss: 14.2808 - val_y1_output_root_mean_squared_error: 2.2724 - val_y2_output_root_mean_squared_error: 3.8441
# Epoch 26/500
# 614/614 [==============================] - 0s 165us/sample - loss: 15.6287 - y1_output_loss: 5.9089 - y2_output_loss: 9.6013 - y1_output_root_mean_squared_error: 2.4417 - y2_output_root_mean_squared_error: 3.1091 - val_loss: 13.0034 - val_y1_output_loss: 4.2090 - val_y2_output_loss: 8.5124 - val_y1_output_root_mean_squared_error: 2.0765 - val_y2_output_root_mean_squared_error: 2.9481
# Epoch 27/500
# 614/614 [==============================] - 0s 162us/sample - loss: 11.4419 - y1_output_loss: 4.8310 - y2_output_loss: 6.6316 - y1_output_root_mean_squared_error: 2.1994 - y2_output_root_mean_squared_error: 2.5699 - val_loss: 16.2840 - val_y1_output_loss: 4.1363 - val_y2_output_loss: 11.6235 - val_y1_output_root_mean_squared_error: 2.0639 - val_y2_output_root_mean_squared_error: 3.4676
# Epoch 28/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.4125 - y1_output_loss: 5.2432 - y2_output_loss: 9.1287 - y1_output_root_mean_squared_error: 2.2955 - y2_output_root_mean_squared_error: 3.0238 - val_loss: 15.2451 - val_y1_output_loss: 5.2750 - val_y2_output_loss: 9.5682 - val_y1_output_root_mean_squared_error: 2.3315 - val_y2_output_root_mean_squared_error: 3.1320
# Epoch 29/500
# 614/614 [==============================] - 0s 149us/sample - loss: 11.3836 - y1_output_loss: 4.5861 - y2_output_loss: 7.1565 - y1_output_root_mean_squared_error: 2.1292 - y2_output_root_mean_squared_error: 2.6173 - val_loss: 52.4881 - val_y1_output_loss: 8.6888 - val_y2_output_loss: 43.1525 - val_y1_output_root_mean_squared_error: 2.9919 - val_y2_output_root_mean_squared_error: 6.5982
# Epoch 30/500
# 614/614 [==============================] - 0s 161us/sample - loss: 15.3054 - y1_output_loss: 5.3383 - y2_output_loss: 9.8317 - y1_output_root_mean_squared_error: 2.3212 - y2_output_root_mean_squared_error: 3.1492 - val_loss: 23.5735 - val_y1_output_loss: 4.5691 - val_y2_output_loss: 18.2873 - val_y1_output_root_mean_squared_error: 2.1648 - val_y2_output_root_mean_squared_error: 4.3460
# Epoch 31/500
# 614/614 [==============================] - 0s 159us/sample - loss: 11.1807 - y1_output_loss: 4.2459 - y2_output_loss: 6.8405 - y1_output_root_mean_squared_error: 2.0706 - y2_output_root_mean_squared_error: 2.6255 - val_loss: 11.6784 - val_y1_output_loss: 3.2910 - val_y2_output_loss: 8.0022 - val_y1_output_root_mean_squared_error: 1.8408 - val_y2_output_root_mean_squared_error: 2.8792
# Epoch 32/500
# 614/614 [==============================] - 0s 173us/sample - loss: 10.2730 - y1_output_loss: 4.0311 - y2_output_loss: 6.2911 - y1_output_root_mean_squared_error: 2.0010 - y2_output_root_mean_squared_error: 2.5038 - val_loss: 14.9866 - val_y1_output_loss: 3.5845 - val_y2_output_loss: 11.4856 - val_y1_output_root_mean_squared_error: 1.9090 - val_y2_output_root_mean_squared_error: 3.3678
# Epoch 33/500
# 614/614 [==============================] - 0s 153us/sample - loss: 9.7014 - y1_output_loss: 3.9598 - y2_output_loss: 6.0035 - y1_output_root_mean_squared_error: 1.9626 - y2_output_root_mean_squared_error: 2.4186 - val_loss: 18.1412 - val_y1_output_loss: 5.6419 - val_y2_output_loss: 11.8997 - val_y1_output_root_mean_squared_error: 2.4114 - val_y2_output_root_mean_squared_error: 3.5109
# Epoch 34/500
# 614/614 [==============================] - 0s 154us/sample - loss: 10.0244 - y1_output_loss: 3.6506 - y2_output_loss: 6.3957 - y1_output_root_mean_squared_error: 1.9009 - y2_output_root_mean_squared_error: 2.5320 - val_loss: 17.3691 - val_y1_output_loss: 4.2185 - val_y2_output_loss: 12.6868 - val_y1_output_root_mean_squared_error: 2.0697 - val_y2_output_root_mean_squared_error: 3.6174
# Epoch 35/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.9292 - y1_output_loss: 3.7360 - y2_output_loss: 6.2999 - y1_output_root_mean_squared_error: 1.9177 - y2_output_root_mean_squared_error: 2.5003 - val_loss: 33.7809 - val_y1_output_loss: 8.5314 - val_y2_output_loss: 24.7225 - val_y1_output_root_mean_squared_error: 2.9645 - val_y2_output_root_mean_squared_error: 4.9993
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.2302 - y1_output_loss: 3.2790 - y2_output_loss: 6.0023 - y1_output_root_mean_squared_error: 1.8034 - y2_output_root_mean_squared_error: 2.4450 - val_loss: 13.2585 - val_y1_output_loss: 5.1491 - val_y2_output_loss: 7.8984 - val_y1_output_root_mean_squared_error: 2.2925 - val_y2_output_root_mean_squared_error: 2.8290
# Epoch 37/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.4313 - y1_output_loss: 3.1858 - y2_output_loss: 5.2817 - y1_output_root_mean_squared_error: 1.7814 - y2_output_root_mean_squared_error: 2.2930 - val_loss: 17.6835 - val_y1_output_loss: 4.9759 - val_y2_output_loss: 12.2481 - val_y1_output_root_mean_squared_error: 2.2541 - val_y2_output_root_mean_squared_error: 3.5500
# Epoch 38/500
# 614/614 [==============================] - 0s 180us/sample - loss: 8.6362 - y1_output_loss: 3.1526 - y2_output_loss: 5.5115 - y1_output_root_mean_squared_error: 1.7785 - y2_output_root_mean_squared_error: 2.3395 - val_loss: 14.2959 - val_y1_output_loss: 2.5626 - val_y2_output_loss: 11.2199 - val_y1_output_root_mean_squared_error: 1.6264 - val_y2_output_root_mean_squared_error: 3.4133
# Epoch 39/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.1046 - y1_output_loss: 2.9267 - y2_output_loss: 5.1321 - y1_output_root_mean_squared_error: 1.7140 - y2_output_root_mean_squared_error: 2.2730 - val_loss: 10.7722 - val_y1_output_loss: 2.4753 - val_y2_output_loss: 7.9389 - val_y1_output_root_mean_squared_error: 1.5984 - val_y2_output_root_mean_squared_error: 2.8666
# Epoch 40/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.7078 - y1_output_loss: 3.2040 - y2_output_loss: 5.4478 - y1_output_root_mean_squared_error: 1.7933 - y2_output_root_mean_squared_error: 2.3435 - val_loss: 8.8465 - val_y1_output_loss: 2.8905 - val_y2_output_loss: 5.7273 - val_y1_output_root_mean_squared_error: 1.7274 - val_y2_output_root_mean_squared_error: 2.4213
# Epoch 41/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.6196 - y1_output_loss: 2.7317 - y2_output_loss: 4.9812 - y1_output_root_mean_squared_error: 1.6587 - y2_output_root_mean_squared_error: 2.2065 - val_loss: 19.4496 - val_y1_output_loss: 3.7184 - val_y2_output_loss: 15.7606 - val_y1_output_root_mean_squared_error: 1.9430 - val_y2_output_root_mean_squared_error: 3.9591
# Epoch 42/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.2580 - y1_output_loss: 2.9280 - y2_output_loss: 5.4123 - y1_output_root_mean_squared_error: 1.7024 - y2_output_root_mean_squared_error: 2.3151 - val_loss: 13.4744 - val_y1_output_loss: 2.6142 - val_y2_output_loss: 10.3794 - val_y1_output_root_mean_squared_error: 1.6454 - val_y2_output_root_mean_squared_error: 3.2813
# Epoch 43/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.7146 - y1_output_loss: 2.6952 - y2_output_loss: 5.0164 - y1_output_root_mean_squared_error: 1.6432 - y2_output_root_mean_squared_error: 2.2393 - val_loss: 9.6065 - val_y1_output_loss: 2.3567 - val_y2_output_loss: 6.9537 - val_y1_output_root_mean_squared_error: 1.5588 - val_y2_output_root_mean_squared_error: 2.6789
# Epoch 44/500
# 614/614 [==============================] - 0s 178us/sample - loss: 7.5935 - y1_output_loss: 2.6496 - y2_output_loss: 5.0340 - y1_output_root_mean_squared_error: 1.6260 - y2_output_root_mean_squared_error: 2.2248 - val_loss: 19.1337 - val_y1_output_loss: 4.1011 - val_y2_output_loss: 14.6037 - val_y1_output_root_mean_squared_error: 2.0628 - val_y2_output_root_mean_squared_error: 3.8573
# Epoch 45/500
# 614/614 [==============================] - 0s 165us/sample - loss: 9.0191 - y1_output_loss: 3.1403 - y2_output_loss: 6.1868 - y1_output_root_mean_squared_error: 1.7645 - y2_output_root_mean_squared_error: 2.4302 - val_loss: 71.4292 - val_y1_output_loss: 14.9863 - val_y2_output_loss: 56.0994 - val_y1_output_root_mean_squared_error: 3.8889 - val_y2_output_root_mean_squared_error: 7.5037
# Epoch 46/500
# 614/614 [==============================] - 0s 172us/sample - loss: 12.0404 - y1_output_loss: 3.7664 - y2_output_loss: 8.2227 - y1_output_root_mean_squared_error: 1.9375 - y2_output_root_mean_squared_error: 2.8786 - val_loss: 9.5644 - val_y1_output_loss: 2.1759 - val_y2_output_loss: 7.0551 - val_y1_output_root_mean_squared_error: 1.5022 - val_y2_output_root_mean_squared_error: 2.7033
# Epoch 47/500
# 614/614 [==============================] - 0s 170us/sample - loss: 7.3460 - y1_output_loss: 2.5323 - y2_output_loss: 4.8382 - y1_output_root_mean_squared_error: 1.5897 - y2_output_root_mean_squared_error: 2.1952 - val_loss: 8.5585 - val_y1_output_loss: 2.3518 - val_y2_output_loss: 6.1044 - val_y1_output_root_mean_squared_error: 1.5500 - val_y2_output_root_mean_squared_error: 2.4812
# Epoch 48/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.7832 - y1_output_loss: 2.9698 - y2_output_loss: 5.7792 - y1_output_root_mean_squared_error: 1.7173 - y2_output_root_mean_squared_error: 2.4154 - val_loss: 7.8364 - val_y1_output_loss: 2.1652 - val_y2_output_loss: 5.4678 - val_y1_output_root_mean_squared_error: 1.4928 - val_y2_output_root_mean_squared_error: 2.3681
# Epoch 49/500
# 614/614 [==============================] - 0s 167us/sample - loss: 10.0164 - y1_output_loss: 3.4959 - y2_output_loss: 6.4339 - y1_output_root_mean_squared_error: 1.8772 - y2_output_root_mean_squared_error: 2.5480 - val_loss: 8.5829 - val_y1_output_loss: 2.4089 - val_y2_output_loss: 5.8705 - val_y1_output_root_mean_squared_error: 1.5804 - val_y2_output_root_mean_squared_error: 2.4668
# Epoch 50/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.0738 - y1_output_loss: 2.6486 - y2_output_loss: 4.5187 - y1_output_root_mean_squared_error: 1.6163 - y2_output_root_mean_squared_error: 2.1122 - val_loss: 19.1551 - val_y1_output_loss: 2.8681 - val_y2_output_loss: 15.6209 - val_y1_output_root_mean_squared_error: 1.7246 - val_y2_output_root_mean_squared_error: 4.0225
# Epoch 51/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.2989 - y1_output_loss: 2.5772 - y2_output_loss: 4.6602 - y1_output_root_mean_squared_error: 1.6114 - y2_output_root_mean_squared_error: 2.1685 - val_loss: 7.2022 - val_y1_output_loss: 1.6826 - val_y2_output_loss: 5.3079 - val_y1_output_root_mean_squared_error: 1.3202 - val_y2_output_root_mean_squared_error: 2.3365
# Epoch 52/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.6700 - y1_output_loss: 2.4976 - y2_output_loss: 5.1388 - y1_output_root_mean_squared_error: 1.5878 - y2_output_root_mean_squared_error: 2.2691 - val_loss: 14.0048 - val_y1_output_loss: 4.3183 - val_y2_output_loss: 9.8653 - val_y1_output_root_mean_squared_error: 2.0743 - val_y2_output_root_mean_squared_error: 3.1148
# Epoch 53/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.4278 - y1_output_loss: 2.4779 - y2_output_loss: 4.9574 - y1_output_root_mean_squared_error: 1.5815 - y2_output_root_mean_squared_error: 2.2196 - val_loss: 15.6840 - val_y1_output_loss: 3.7623 - val_y2_output_loss: 11.9338 - val_y1_output_root_mean_squared_error: 1.9572 - val_y2_output_root_mean_squared_error: 3.4429
# Epoch 54/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.3434 - y1_output_loss: 2.3676 - y2_output_loss: 5.0068 - y1_output_root_mean_squared_error: 1.5270 - y2_output_root_mean_squared_error: 2.2387 - val_loss: 18.6284 - val_y1_output_loss: 5.2127 - val_y2_output_loss: 12.8100 - val_y1_output_root_mean_squared_error: 2.3153 - val_y2_output_root_mean_squared_error: 3.6425
# Epoch 55/500
# 614/614 [==============================] - 0s 169us/sample - loss: 7.9017 - y1_output_loss: 2.5807 - y2_output_loss: 5.3256 - y1_output_root_mean_squared_error: 1.6103 - y2_output_root_mean_squared_error: 2.3041 - val_loss: 6.8634 - val_y1_output_loss: 1.8288 - val_y2_output_loss: 4.8037 - val_y1_output_root_mean_squared_error: 1.3725 - val_y2_output_root_mean_squared_error: 2.2315
# Epoch 56/500
# 614/614 [==============================] - 0s 154us/sample - loss: 6.2990 - y1_output_loss: 2.0947 - y2_output_loss: 4.2446 - y1_output_root_mean_squared_error: 1.4466 - y2_output_root_mean_squared_error: 2.0510 - val_loss: 8.2891 - val_y1_output_loss: 3.0714 - val_y2_output_loss: 5.0977 - val_y1_output_root_mean_squared_error: 1.7614 - val_y2_output_root_mean_squared_error: 2.2774
# Epoch 57/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.1767 - y1_output_loss: 2.3997 - y2_output_loss: 4.7433 - y1_output_root_mean_squared_error: 1.5546 - y2_output_root_mean_squared_error: 2.1817 - val_loss: 7.6102 - val_y1_output_loss: 1.7337 - val_y2_output_loss: 5.6388 - val_y1_output_root_mean_squared_error: 1.3364 - val_y2_output_root_mean_squared_error: 2.4133
# Epoch 58/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.7666 - y1_output_loss: 2.1250 - y2_output_loss: 4.6472 - y1_output_root_mean_squared_error: 1.4510 - y2_output_root_mean_squared_error: 2.1590 - val_loss: 12.9019 - val_y1_output_loss: 5.6972 - val_y2_output_loss: 7.3170 - val_y1_output_root_mean_squared_error: 2.3822 - val_y2_output_root_mean_squared_error: 2.6883
# Epoch 59/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.1913 - y1_output_loss: 2.7064 - y2_output_loss: 5.4326 - y1_output_root_mean_squared_error: 1.6489 - y2_output_root_mean_squared_error: 2.3393 - val_loss: 8.0576 - val_y1_output_loss: 1.7225 - val_y2_output_loss: 6.0795 - val_y1_output_root_mean_squared_error: 1.3273 - val_y2_output_root_mean_squared_error: 2.5092
# Epoch 60/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.9505 - y1_output_loss: 3.2328 - y2_output_loss: 6.6500 - y1_output_root_mean_squared_error: 1.8014 - y2_output_root_mean_squared_error: 2.5895 - val_loss: 9.0131 - val_y1_output_loss: 1.7558 - val_y2_output_loss: 6.9455 - val_y1_output_root_mean_squared_error: 1.3439 - val_y2_output_root_mean_squared_error: 2.6846
# Epoch 61/500
# 614/614 [==============================] - 0s 179us/sample - loss: 6.7196 - y1_output_loss: 2.1194 - y2_output_loss: 4.5695 - y1_output_root_mean_squared_error: 1.4588 - y2_output_root_mean_squared_error: 2.1428 - val_loss: 9.7770 - val_y1_output_loss: 1.8855 - val_y2_output_loss: 7.5617 - val_y1_output_root_mean_squared_error: 1.3931 - val_y2_output_root_mean_squared_error: 2.7993
# Epoch 62/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.9197 - y1_output_loss: 2.3238 - y2_output_loss: 4.6180 - y1_output_root_mean_squared_error: 1.5237 - y2_output_root_mean_squared_error: 2.1443 - val_loss: 7.2553 - val_y1_output_loss: 1.9921 - val_y2_output_loss: 5.0539 - val_y1_output_root_mean_squared_error: 1.4356 - val_y2_output_root_mean_squared_error: 2.2791
# Epoch 63/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.6893 - y1_output_loss: 1.8672 - y2_output_loss: 3.7999 - y1_output_root_mean_squared_error: 1.3703 - y2_output_root_mean_squared_error: 1.9523 - val_loss: 6.2940 - val_y1_output_loss: 1.6891 - val_y2_output_loss: 4.4461 - val_y1_output_root_mean_squared_error: 1.3196 - val_y2_output_root_mean_squared_error: 2.1337
# Epoch 64/500
# 614/614 [==============================] - 0s 163us/sample - loss: 13.3174 - y1_output_loss: 4.3419 - y2_output_loss: 8.9115 - y1_output_root_mean_squared_error: 2.0927 - y2_output_root_mean_squared_error: 2.9897 - val_loss: 13.1337 - val_y1_output_loss: 4.1661 - val_y2_output_loss: 9.0566 - val_y1_output_root_mean_squared_error: 2.0435 - val_y2_output_root_mean_squared_error: 2.9930
# Epoch 65/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.2828 - y1_output_loss: 2.1557 - y2_output_loss: 4.1276 - y1_output_root_mean_squared_error: 1.4559 - y2_output_root_mean_squared_error: 2.0404 - val_loss: 12.0665 - val_y1_output_loss: 2.5774 - val_y2_output_loss: 9.0955 - val_y1_output_root_mean_squared_error: 1.6290 - val_y2_output_root_mean_squared_error: 3.0681
# Epoch 66/500
# 614/614 [==============================] - 0s 179us/sample - loss: 6.5039 - y1_output_loss: 2.0372 - y2_output_loss: 4.4274 - y1_output_root_mean_squared_error: 1.4279 - y2_output_root_mean_squared_error: 2.1130 - val_loss: 6.6558 - val_y1_output_loss: 1.4556 - val_y2_output_loss: 4.9900 - val_y1_output_root_mean_squared_error: 1.2250 - val_y2_output_root_mean_squared_error: 2.2705
# Epoch 67/500
# 614/614 [==============================] - 0s 179us/sample - loss: 10.5480 - y1_output_loss: 3.5646 - y2_output_loss: 7.2772 - y1_output_root_mean_squared_error: 1.8646 - y2_output_root_mean_squared_error: 2.6592 - val_loss: 30.1178 - val_y1_output_loss: 7.4706 - val_y2_output_loss: 22.1849 - val_y1_output_root_mean_squared_error: 2.7351 - val_y2_output_root_mean_squared_error: 4.7578
# Epoch 68/500
# 614/614 [==============================] - 0s 163us/sample - loss: 6.1731 - y1_output_loss: 2.1021 - y2_output_loss: 4.0468 - y1_output_root_mean_squared_error: 1.4536 - y2_output_root_mean_squared_error: 2.0150 - val_loss: 9.4281 - val_y1_output_loss: 1.4222 - val_y2_output_loss: 7.7192 - val_y1_output_root_mean_squared_error: 1.2000 - val_y2_output_root_mean_squared_error: 2.8263
# Epoch 69/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.8744 - y1_output_loss: 1.5889 - y2_output_loss: 3.3090 - y1_output_root_mean_squared_error: 1.2636 - y2_output_root_mean_squared_error: 1.8105 - val_loss: 5.9326 - val_y1_output_loss: 1.4404 - val_y2_output_loss: 4.3524 - val_y1_output_root_mean_squared_error: 1.2215 - val_y2_output_root_mean_squared_error: 2.1072
# Epoch 70/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.2513 - y1_output_loss: 1.5134 - y2_output_loss: 3.7333 - y1_output_root_mean_squared_error: 1.2348 - y2_output_root_mean_squared_error: 1.9304 - val_loss: 9.4468 - val_y1_output_loss: 1.3481 - val_y2_output_loss: 7.8483 - val_y1_output_root_mean_squared_error: 1.1662 - val_y2_output_root_mean_squared_error: 2.8437
# Epoch 71/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.7291 - y1_output_loss: 1.9821 - y2_output_loss: 4.7639 - y1_output_root_mean_squared_error: 1.4060 - y2_output_root_mean_squared_error: 2.1800 - val_loss: 24.7840 - val_y1_output_loss: 8.9884 - val_y2_output_loss: 15.3810 - val_y1_output_root_mean_squared_error: 3.0355 - val_y2_output_root_mean_squared_error: 3.9459
# Epoch 72/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.8117 - y1_output_loss: 2.6392 - y2_output_loss: 5.1206 - y1_output_root_mean_squared_error: 1.6295 - y2_output_root_mean_squared_error: 2.2708 - val_loss: 7.3690 - val_y1_output_loss: 1.1006 - val_y2_output_loss: 6.0127 - val_y1_output_root_mean_squared_error: 1.0663 - val_y2_output_root_mean_squared_error: 2.4964
# Epoch 73/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.2571 - y1_output_loss: 1.7020 - y2_output_loss: 4.5473 - y1_output_root_mean_squared_error: 1.3055 - y2_output_root_mean_squared_error: 2.1337 - val_loss: 5.8612 - val_y1_output_loss: 1.0716 - val_y2_output_loss: 4.6038 - val_y1_output_root_mean_squared_error: 1.0434 - val_y2_output_root_mean_squared_error: 2.1846
# Epoch 74/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.5806 - y1_output_loss: 1.6706 - y2_output_loss: 3.8636 - y1_output_root_mean_squared_error: 1.2974 - y2_output_root_mean_squared_error: 1.9742 - val_loss: 5.8318 - val_y1_output_loss: 1.0538 - val_y2_output_loss: 4.5719 - val_y1_output_root_mean_squared_error: 1.0427 - val_y2_output_root_mean_squared_error: 2.1782
# Epoch 75/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.2748 - y1_output_loss: 1.5745 - y2_output_loss: 3.6952 - y1_output_root_mean_squared_error: 1.2578 - y2_output_root_mean_squared_error: 1.9216 - val_loss: 8.0851 - val_y1_output_loss: 1.9505 - val_y2_output_loss: 6.0737 - val_y1_output_root_mean_squared_error: 1.4112 - val_y2_output_root_mean_squared_error: 2.4685
# Epoch 76/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.2180 - y1_output_loss: 1.5423 - y2_output_loss: 3.6663 - y1_output_root_mean_squared_error: 1.2456 - y2_output_root_mean_squared_error: 1.9148 - val_loss: 4.4297 - val_y1_output_loss: 0.9501 - val_y2_output_loss: 3.3298 - val_y1_output_root_mean_squared_error: 0.9859 - val_y2_output_root_mean_squared_error: 1.8595
# Epoch 77/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.5159 - y1_output_loss: 1.3193 - y2_output_loss: 3.1899 - y1_output_root_mean_squared_error: 1.1535 - y2_output_root_mean_squared_error: 1.7847 - val_loss: 9.5100 - val_y1_output_loss: 2.1475 - val_y2_output_loss: 7.2205 - val_y1_output_root_mean_squared_error: 1.4879 - val_y2_output_root_mean_squared_error: 2.7011
# Epoch 78/500
# 614/614 [==============================] - 0s 168us/sample - loss: 4.8820 - y1_output_loss: 1.2078 - y2_output_loss: 3.6402 - y1_output_root_mean_squared_error: 1.1011 - y2_output_root_mean_squared_error: 1.9156 - val_loss: 4.5108 - val_y1_output_loss: 0.9761 - val_y2_output_loss: 3.4069 - val_y1_output_root_mean_squared_error: 1.0048 - val_y2_output_root_mean_squared_error: 1.8711
# Epoch 79/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.7245 - y1_output_loss: 0.9722 - y2_output_loss: 2.7445 - y1_output_root_mean_squared_error: 0.9899 - y2_output_root_mean_squared_error: 1.6567 - val_loss: 4.6767 - val_y1_output_loss: 1.0810 - val_y2_output_loss: 3.5320 - val_y1_output_root_mean_squared_error: 1.0449 - val_y2_output_root_mean_squared_error: 1.8934
# Epoch 80/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.0886 - y1_output_loss: 0.9481 - y2_output_loss: 3.1484 - y1_output_root_mean_squared_error: 0.9652 - y2_output_root_mean_squared_error: 1.7768 - val_loss: 3.9569 - val_y1_output_loss: 0.7196 - val_y2_output_loss: 3.1214 - val_y1_output_root_mean_squared_error: 0.8601 - val_y2_output_root_mean_squared_error: 1.7936
# Epoch 81/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.9610 - y1_output_loss: 1.2818 - y2_output_loss: 3.7219 - y1_output_root_mean_squared_error: 1.1257 - y2_output_root_mean_squared_error: 1.9220 - val_loss: 8.0474 - val_y1_output_loss: 1.9956 - val_y2_output_loss: 5.9375 - val_y1_output_root_mean_squared_error: 1.4291 - val_y2_output_root_mean_squared_error: 2.4505
# Epoch 82/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.2676 - y1_output_loss: 1.1658 - y2_output_loss: 3.1079 - y1_output_root_mean_squared_error: 1.0699 - y2_output_root_mean_squared_error: 1.7672 - val_loss: 5.5202 - val_y1_output_loss: 1.9171 - val_y2_output_loss: 3.5860 - val_y1_output_root_mean_squared_error: 1.3709 - val_y2_output_root_mean_squared_error: 1.9081
# Epoch 83/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.3269 - y1_output_loss: 0.8365 - y2_output_loss: 2.4675 - y1_output_root_mean_squared_error: 0.9155 - y2_output_root_mean_squared_error: 1.5776 - val_loss: 6.8523 - val_y1_output_loss: 1.1064 - val_y2_output_loss: 5.4941 - val_y1_output_root_mean_squared_error: 1.0699 - val_y2_output_root_mean_squared_error: 2.3891
# Epoch 84/500
# 614/614 [==============================] - 0s 171us/sample - loss: 3.9004 - y1_output_loss: 0.9708 - y2_output_loss: 2.9135 - y1_output_root_mean_squared_error: 0.9833 - y2_output_root_mean_squared_error: 1.7127 - val_loss: 3.2754 - val_y1_output_loss: 0.4987 - val_y2_output_loss: 2.6743 - val_y1_output_root_mean_squared_error: 0.7115 - val_y2_output_root_mean_squared_error: 1.6641
# Epoch 85/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.1440 - y1_output_loss: 0.7139 - y2_output_loss: 2.4416 - y1_output_root_mean_squared_error: 0.8440 - y2_output_root_mean_squared_error: 1.5594 - val_loss: 4.4685 - val_y1_output_loss: 0.7261 - val_y2_output_loss: 3.5869 - val_y1_output_root_mean_squared_error: 0.8636 - val_y2_output_root_mean_squared_error: 1.9294
# Epoch 86/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.0231 - y1_output_loss: 0.7327 - y2_output_loss: 2.2699 - y1_output_root_mean_squared_error: 0.8553 - y2_output_root_mean_squared_error: 1.5138 - val_loss: 4.7315 - val_y1_output_loss: 0.4510 - val_y2_output_loss: 4.1084 - val_y1_output_root_mean_squared_error: 0.6812 - val_y2_output_root_mean_squared_error: 2.0658
# Epoch 87/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.6967 - y1_output_loss: 1.0444 - y2_output_loss: 2.6611 - y1_output_root_mean_squared_error: 1.0255 - y2_output_root_mean_squared_error: 1.6264 - val_loss: 3.7071 - val_y1_output_loss: 0.8254 - val_y2_output_loss: 2.7663 - val_y1_output_root_mean_squared_error: 0.9200 - val_y2_output_root_mean_squared_error: 1.6914
# Epoch 88/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.7303 - y1_output_loss: 2.1179 - y2_output_loss: 4.5716 - y1_output_root_mean_squared_error: 1.4592 - y2_output_root_mean_squared_error: 2.1450 - val_loss: 4.7826 - val_y1_output_loss: 0.9391 - val_y2_output_loss: 3.7205 - val_y1_output_root_mean_squared_error: 0.9701 - val_y2_output_root_mean_squared_error: 1.9600
# Epoch 89/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.2673 - y1_output_loss: 1.0818 - y2_output_loss: 3.1542 - y1_output_root_mean_squared_error: 1.0438 - y2_output_root_mean_squared_error: 1.7826 - val_loss: 4.6269 - val_y1_output_loss: 0.5375 - val_y2_output_loss: 3.9309 - val_y1_output_root_mean_squared_error: 0.7414 - val_y2_output_root_mean_squared_error: 2.0192
# Epoch 90/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.2678 - y1_output_loss: 0.9064 - y2_output_loss: 2.3811 - y1_output_root_mean_squared_error: 0.9536 - y2_output_root_mean_squared_error: 1.5358 - val_loss: 6.4278 - val_y1_output_loss: 2.6687 - val_y2_output_loss: 3.6703 - val_y1_output_root_mean_squared_error: 1.6389 - val_y2_output_root_mean_squared_error: 1.9344
# Epoch 91/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.4927 - y1_output_loss: 1.2684 - y2_output_loss: 3.2063 - y1_output_root_mean_squared_error: 1.1277 - y2_output_root_mean_squared_error: 1.7947 - val_loss: 4.2669 - val_y1_output_loss: 0.7531 - val_y2_output_loss: 3.4253 - val_y1_output_root_mean_squared_error: 0.8825 - val_y2_output_root_mean_squared_error: 1.8676
# Epoch 92/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.0096 - y1_output_loss: 1.7319 - y2_output_loss: 5.2571 - y1_output_root_mean_squared_error: 1.3153 - y2_output_root_mean_squared_error: 2.2977 - val_loss: 10.7432 - val_y1_output_loss: 1.6821 - val_y2_output_loss: 8.8950 - val_y1_output_root_mean_squared_error: 1.2851 - val_y2_output_root_mean_squared_error: 3.0153
# Epoch 93/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.2280 - y1_output_loss: 0.8298 - y2_output_loss: 2.3964 - y1_output_root_mean_squared_error: 0.9099 - y2_output_root_mean_squared_error: 1.5492 - val_loss: 5.3530 - val_y1_output_loss: 1.2382 - val_y2_output_loss: 3.9374 - val_y1_output_root_mean_squared_error: 1.1292 - val_y2_output_root_mean_squared_error: 2.0194
# Epoch 94/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.0493 - y1_output_loss: 1.2803 - y2_output_loss: 3.7304 - y1_output_root_mean_squared_error: 1.1364 - y2_output_root_mean_squared_error: 1.9385 - val_loss: 5.3049 - val_y1_output_loss: 0.6941 - val_y2_output_loss: 4.5131 - val_y1_output_root_mean_squared_error: 0.8264 - val_y2_output_root_mean_squared_error: 2.1499
# Epoch 95/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.8773 - y1_output_loss: 1.0024 - y2_output_loss: 2.8506 - y1_output_root_mean_squared_error: 1.0058 - y2_output_root_mean_squared_error: 1.6928 - val_loss: 3.1222 - val_y1_output_loss: 0.4854 - val_y2_output_loss: 2.5453 - val_y1_output_root_mean_squared_error: 0.7005 - val_y2_output_root_mean_squared_error: 1.6222
# Epoch 96/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.9116 - y1_output_loss: 1.3143 - y2_output_loss: 3.6186 - y1_output_root_mean_squared_error: 1.1337 - y2_output_root_mean_squared_error: 1.9043 - val_loss: 7.3904 - val_y1_output_loss: 3.1057 - val_y2_output_loss: 4.0543 - val_y1_output_root_mean_squared_error: 1.7925 - val_y2_output_root_mean_squared_error: 2.0439
# Epoch 97/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.4799 - y1_output_loss: 1.2427 - y2_output_loss: 3.2104 - y1_output_root_mean_squared_error: 1.1183 - y2_output_root_mean_squared_error: 1.7970 - val_loss: 6.1515 - val_y1_output_loss: 2.0234 - val_y2_output_loss: 3.9668 - val_y1_output_root_mean_squared_error: 1.4453 - val_y2_output_root_mean_squared_error: 2.0156
# Epoch 98/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.4023 - y1_output_loss: 0.8487 - y2_output_loss: 2.5726 - y1_output_root_mean_squared_error: 0.9171 - y2_output_root_mean_squared_error: 1.6004 - val_loss: 4.4319 - val_y1_output_loss: 0.6390 - val_y2_output_loss: 3.6317 - val_y1_output_root_mean_squared_error: 0.8130 - val_y2_output_root_mean_squared_error: 1.9419
# Epoch 99/500
# 614/614 [==============================] - 0s 171us/sample - loss: 3.2453 - y1_output_loss: 0.6752 - y2_output_loss: 2.5440 - y1_output_root_mean_squared_error: 0.8230 - y2_output_root_mean_squared_error: 1.6025 - val_loss: 3.6989 - val_y1_output_loss: 0.4564 - val_y2_output_loss: 3.1169 - val_y1_output_root_mean_squared_error: 0.6817 - val_y2_output_root_mean_squared_error: 1.7984
# Epoch 100/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.7153 - y1_output_loss: 0.5622 - y2_output_loss: 2.1570 - y1_output_root_mean_squared_error: 0.7508 - y2_output_root_mean_squared_error: 1.4668 - val_loss: 3.0293 - val_y1_output_loss: 0.5314 - val_y2_output_loss: 2.4287 - val_y1_output_root_mean_squared_error: 0.7339 - val_y2_output_root_mean_squared_error: 1.5782
# Epoch 101/500
# 614/614 [==============================] - 0s 179us/sample - loss: 3.9783 - y1_output_loss: 1.0821 - y2_output_loss: 3.0334 - y1_output_root_mean_squared_error: 1.0382 - y2_output_root_mean_squared_error: 1.7030 - val_loss: 14.1275 - val_y1_output_loss: 1.9074 - val_y2_output_loss: 11.9041 - val_y1_output_root_mean_squared_error: 1.3909 - val_y2_output_root_mean_squared_error: 3.4918
# Epoch 102/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.2930 - y1_output_loss: 0.8815 - y2_output_loss: 2.3967 - y1_output_root_mean_squared_error: 0.9396 - y2_output_root_mean_squared_error: 1.5525 - val_loss: 3.8572 - val_y1_output_loss: 0.7717 - val_y2_output_loss: 2.9795 - val_y1_output_root_mean_squared_error: 0.8902 - val_y2_output_root_mean_squared_error: 1.7506
# Epoch 103/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.3588 - y1_output_loss: 0.5181 - y2_output_loss: 1.8896 - y1_output_root_mean_squared_error: 0.7222 - y2_output_root_mean_squared_error: 1.3554 - val_loss: 3.8769 - val_y1_output_loss: 0.5030 - val_y2_output_loss: 3.3289 - val_y1_output_root_mean_squared_error: 0.7206 - val_y2_output_root_mean_squared_error: 1.8324
# Epoch 104/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.1016 - y1_output_loss: 0.7009 - y2_output_loss: 2.3888 - y1_output_root_mean_squared_error: 0.8379 - y2_output_root_mean_squared_error: 1.5490 - val_loss: 3.3018 - val_y1_output_loss: 0.4592 - val_y2_output_loss: 2.7280 - val_y1_output_root_mean_squared_error: 0.6850 - val_y2_output_root_mean_squared_error: 1.6830
# Epoch 105/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.7364 - y1_output_loss: 0.6906 - y2_output_loss: 2.1239 - y1_output_root_mean_squared_error: 0.8171 - y2_output_root_mean_squared_error: 1.4383 - val_loss: 22.0190 - val_y1_output_loss: 4.9808 - val_y2_output_loss: 16.8367 - val_y1_output_root_mean_squared_error: 2.2201 - val_y2_output_root_mean_squared_error: 4.1340
# Epoch 106/500
# 614/614 [==============================] - 0s 155us/sample - loss: 5.5943 - y1_output_loss: 1.3657 - y2_output_loss: 4.1954 - y1_output_root_mean_squared_error: 1.1723 - y2_output_root_mean_squared_error: 2.0542 - val_loss: 3.9924 - val_y1_output_loss: 0.4880 - val_y2_output_loss: 3.3634 - val_y1_output_root_mean_squared_error: 0.7076 - val_y2_output_root_mean_squared_error: 1.8686
# Epoch 107/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.1787 - y1_output_loss: 0.7092 - y2_output_loss: 2.4454 - y1_output_root_mean_squared_error: 0.8452 - y2_output_root_mean_squared_error: 1.5698 - val_loss: 3.2328 - val_y1_output_loss: 0.5091 - val_y2_output_loss: 2.6253 - val_y1_output_root_mean_squared_error: 0.7170 - val_y2_output_root_mean_squared_error: 1.6488
# Epoch 108/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3505 - y1_output_loss: 0.4825 - y2_output_loss: 1.8641 - y1_output_root_mean_squared_error: 0.6932 - y2_output_root_mean_squared_error: 1.3675 - val_loss: 3.0614 - val_y1_output_loss: 0.5324 - val_y2_output_loss: 2.4966 - val_y1_output_root_mean_squared_error: 0.7282 - val_y2_output_root_mean_squared_error: 1.5909
# Epoch 109/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.0187 - y1_output_loss: 0.6169 - y2_output_loss: 2.3930 - y1_output_root_mean_squared_error: 0.7884 - y2_output_root_mean_squared_error: 1.5483 - val_loss: 2.8813 - val_y1_output_loss: 0.4600 - val_y2_output_loss: 2.3378 - val_y1_output_root_mean_squared_error: 0.6871 - val_y2_output_root_mean_squared_error: 1.5522
# Epoch 110/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.7971 - y1_output_loss: 0.8288 - y2_output_loss: 2.9904 - y1_output_root_mean_squared_error: 0.9109 - y2_output_root_mean_squared_error: 1.7226 - val_loss: 2.9828 - val_y1_output_loss: 0.6875 - val_y2_output_loss: 2.2127 - val_y1_output_root_mean_squared_error: 0.8364 - val_y2_output_root_mean_squared_error: 1.5110
# Epoch 111/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.5444 - y1_output_loss: 0.5549 - y2_output_loss: 1.9709 - y1_output_root_mean_squared_error: 0.7484 - y2_output_root_mean_squared_error: 1.4087 - val_loss: 3.4532 - val_y1_output_loss: 0.8190 - val_y2_output_loss: 2.5909 - val_y1_output_root_mean_squared_error: 0.9050 - val_y2_output_root_mean_squared_error: 1.6230
# Epoch 112/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.3628 - y1_output_loss: 0.9211 - y2_output_loss: 2.5417 - y1_output_root_mean_squared_error: 0.9331 - y2_output_root_mean_squared_error: 1.5786 - val_loss: 20.8783 - val_y1_output_loss: 7.6999 - val_y2_output_loss: 12.6007 - val_y1_output_root_mean_squared_error: 2.8099 - val_y2_output_root_mean_squared_error: 3.6032
# Epoch 113/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.0654 - y1_output_loss: 1.5596 - y2_output_loss: 3.4743 - y1_output_root_mean_squared_error: 1.2525 - y2_output_root_mean_squared_error: 1.8700 - val_loss: 3.7477 - val_y1_output_loss: 1.0218 - val_y2_output_loss: 2.6446 - val_y1_output_root_mean_squared_error: 1.0206 - val_y2_output_root_mean_squared_error: 1.6450
# Epoch 114/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.6730 - y1_output_loss: 0.6514 - y2_output_loss: 2.0032 - y1_output_root_mean_squared_error: 0.8084 - y2_output_root_mean_squared_error: 1.4211 - val_loss: 2.9197 - val_y1_output_loss: 0.5652 - val_y2_output_loss: 2.2893 - val_y1_output_root_mean_squared_error: 0.7555 - val_y2_output_root_mean_squared_error: 1.5326
# Epoch 115/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.1409 - y1_output_loss: 1.1526 - y2_output_loss: 3.9443 - y1_output_root_mean_squared_error: 1.0767 - y2_output_root_mean_squared_error: 1.9954 - val_loss: 3.5286 - val_y1_output_loss: 0.4128 - val_y2_output_loss: 2.9946 - val_y1_output_root_mean_squared_error: 0.6490 - val_y2_output_root_mean_squared_error: 1.7628
# Epoch 116/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.0506 - y1_output_loss: 0.4154 - y2_output_loss: 1.6237 - y1_output_root_mean_squared_error: 0.6431 - y2_output_root_mean_squared_error: 1.2795 - val_loss: 3.5045 - val_y1_output_loss: 0.5095 - val_y2_output_loss: 2.9319 - val_y1_output_root_mean_squared_error: 0.6965 - val_y2_output_root_mean_squared_error: 1.7376
# Epoch 117/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.2590 - y1_output_loss: 0.4981 - y2_output_loss: 1.7623 - y1_output_root_mean_squared_error: 0.6966 - y2_output_root_mean_squared_error: 1.3318 - val_loss: 3.8209 - val_y1_output_loss: 1.1496 - val_y2_output_loss: 2.5457 - val_y1_output_root_mean_squared_error: 1.0894 - val_y2_output_root_mean_squared_error: 1.6230
# Epoch 118/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.4193 - y1_output_loss: 0.5781 - y2_output_loss: 1.8398 - y1_output_root_mean_squared_error: 0.7609 - y2_output_root_mean_squared_error: 1.3566 - val_loss: 3.3055 - val_y1_output_loss: 0.7425 - val_y2_output_loss: 2.5308 - val_y1_output_root_mean_squared_error: 0.8592 - val_y2_output_root_mean_squared_error: 1.6023
# Epoch 119/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.1179 - y1_output_loss: 0.4882 - y2_output_loss: 1.6122 - y1_output_root_mean_squared_error: 0.7012 - y2_output_root_mean_squared_error: 1.2752 - val_loss: 3.2468 - val_y1_output_loss: 0.3941 - val_y2_output_loss: 2.7465 - val_y1_output_root_mean_squared_error: 0.6355 - val_y2_output_root_mean_squared_error: 1.6861
# Epoch 120/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.5424 - y1_output_loss: 0.8281 - y2_output_loss: 2.6816 - y1_output_root_mean_squared_error: 0.9138 - y2_output_root_mean_squared_error: 1.6454 - val_loss: 2.6110 - val_y1_output_loss: 0.5126 - val_y2_output_loss: 2.0607 - val_y1_output_root_mean_squared_error: 0.7041 - val_y2_output_root_mean_squared_error: 1.4544
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.8092 - y1_output_loss: 0.2120 - y2_output_loss: 0.5943 - y1_output_root_mean_squared_error: 0.4615 - y2_output_root_mean_squared_error: 0.7721 - val_loss: 1.3262 - val_y1_output_loss: 0.1971 - val_y2_output_loss: 1.0907 - val_y1_output_root_mean_squared_error: 0.4483 - val_y2_output_root_mean_squared_error: 1.0608
# Epoch 462/500
# 614/614 [==============================] - 0s 188us/sample - loss: 0.5030 - y1_output_loss: 0.1412 - y2_output_loss: 0.3630 - y1_output_root_mean_squared_error: 0.3744 - y2_output_root_mean_squared_error: 0.6023 - val_loss: 1.2084 - val_y1_output_loss: 0.1975 - val_y2_output_loss: 0.9710 - val_y1_output_root_mean_squared_error: 0.4516 - val_y2_output_root_mean_squared_error: 1.0023
# Epoch 463/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5850 - y1_output_loss: 0.1513 - y2_output_loss: 0.4299 - y1_output_root_mean_squared_error: 0.3904 - y2_output_root_mean_squared_error: 0.6578 - val_loss: 1.1885 - val_y1_output_loss: 0.2004 - val_y2_output_loss: 0.9527 - val_y1_output_root_mean_squared_error: 0.4500 - val_y2_output_root_mean_squared_error: 0.9930
# Epoch 464/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.9261 - y1_output_loss: 0.2141 - y2_output_loss: 0.7134 - y1_output_root_mean_squared_error: 0.4634 - y2_output_root_mean_squared_error: 0.8434 - val_loss: 2.9320 - val_y1_output_loss: 0.3350 - val_y2_output_loss: 2.5243 - val_y1_output_root_mean_squared_error: 0.5830 - val_y2_output_root_mean_squared_error: 1.6100
# Epoch 465/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.6242 - y1_output_loss: 0.1657 - y2_output_loss: 0.4537 - y1_output_root_mean_squared_error: 0.4087 - y2_output_root_mean_squared_error: 0.6761 - val_loss: 1.0931 - val_y1_output_loss: 0.1859 - val_y2_output_loss: 0.8768 - val_y1_output_root_mean_squared_error: 0.4314 - val_y2_output_root_mean_squared_error: 0.9524
# Epoch 466/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.5182 - y1_output_loss: 0.1401 - y2_output_loss: 0.3762 - y1_output_root_mean_squared_error: 0.3744 - y2_output_root_mean_squared_error: 0.6149 - val_loss: 2.1603 - val_y1_output_loss: 0.3838 - val_y2_output_loss: 1.7214 - val_y1_output_root_mean_squared_error: 0.6222 - val_y2_output_root_mean_squared_error: 1.3316
# Epoch 467/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4831 - y1_output_loss: 0.1444 - y2_output_loss: 0.3424 - y1_output_root_mean_squared_error: 0.3814 - y2_output_root_mean_squared_error: 0.5811 - val_loss: 1.1910 - val_y1_output_loss: 0.1911 - val_y2_output_loss: 0.9666 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_root_mean_squared_error: 0.9971
# Epoch 468/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.4414 - y1_output_loss: 0.1179 - y2_output_loss: 0.3265 - y1_output_root_mean_squared_error: 0.3437 - y2_output_root_mean_squared_error: 0.5686 - val_loss: 1.2402 - val_y1_output_loss: 0.1702 - val_y2_output_loss: 1.0376 - val_y1_output_root_mean_squared_error: 0.4155 - val_y2_output_root_mean_squared_error: 1.0332
# Epoch 469/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4092 - y1_output_loss: 0.1187 - y2_output_loss: 0.2878 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5384 - val_loss: 1.0665 - val_y1_output_loss: 0.1702 - val_y2_output_loss: 0.8630 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 0.9442
# Epoch 470/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4090 - y1_output_loss: 0.1314 - y2_output_loss: 0.2755 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 1.1499 - val_y1_output_loss: 0.2186 - val_y2_output_loss: 0.8983 - val_y1_output_root_mean_squared_error: 0.4737 - val_y2_output_root_mean_squared_error: 0.9620
# Epoch 471/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.5918 - y1_output_loss: 0.1505 - y2_output_loss: 0.4526 - y1_output_root_mean_squared_error: 0.3885 - y2_output_root_mean_squared_error: 0.6640 - val_loss: 2.6951 - val_y1_output_loss: 0.2293 - val_y2_output_loss: 2.4025 - val_y1_output_root_mean_squared_error: 0.4814 - val_y2_output_root_mean_squared_error: 1.5695
# Epoch 472/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4668 - y1_output_loss: 0.1260 - y2_output_loss: 0.3385 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.5831 - val_loss: 1.9440 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 1.6989 - val_y1_output_root_mean_squared_error: 0.4546 - val_y2_output_root_mean_squared_error: 1.3181
# Epoch 473/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.6168 - y1_output_loss: 0.1435 - y2_output_loss: 0.4733 - y1_output_root_mean_squared_error: 0.3799 - y2_output_root_mean_squared_error: 0.6874 - val_loss: 2.5061 - val_y1_output_loss: 0.2818 - val_y2_output_loss: 2.1711 - val_y1_output_root_mean_squared_error: 0.5308 - val_y2_output_root_mean_squared_error: 1.4914
# Epoch 474/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.5963 - y1_output_loss: 0.1481 - y2_output_loss: 0.4483 - y1_output_root_mean_squared_error: 0.3832 - y2_output_root_mean_squared_error: 0.6704 - val_loss: 1.3432 - val_y1_output_loss: 0.3084 - val_y2_output_loss: 0.9997 - val_y1_output_root_mean_squared_error: 0.5626 - val_y2_output_root_mean_squared_error: 1.0132
# Epoch 475/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4892 - y1_output_loss: 0.1277 - y2_output_loss: 0.3802 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.6023 - val_loss: 4.0895 - val_y1_output_loss: 0.2761 - val_y2_output_loss: 3.7560 - val_y1_output_root_mean_squared_error: 0.5209 - val_y2_output_root_mean_squared_error: 1.9540
# Epoch 476/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4227 - y1_output_loss: 0.1216 - y2_output_loss: 0.3008 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.5489 - val_loss: 1.6531 - val_y1_output_loss: 0.3310 - val_y2_output_loss: 1.3142 - val_y1_output_root_mean_squared_error: 0.5797 - val_y2_output_root_mean_squared_error: 1.1476
# Epoch 477/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4865 - y1_output_loss: 0.1300 - y2_output_loss: 0.3554 - y1_output_root_mean_squared_error: 0.3614 - y2_output_root_mean_squared_error: 0.5966 - val_loss: 1.1440 - val_y1_output_loss: 0.2279 - val_y2_output_loss: 0.8864 - val_y1_output_root_mean_squared_error: 0.4826 - val_y2_output_root_mean_squared_error: 0.9545
# Epoch 478/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.5103 - y1_output_loss: 0.1316 - y2_output_loss: 0.3780 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.6146 - val_loss: 1.5877 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 1.3683 - val_y1_output_root_mean_squared_error: 0.4233 - val_y2_output_root_mean_squared_error: 1.1868
# Epoch 479/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.5230 - y1_output_loss: 0.1326 - y2_output_loss: 0.3913 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.6253 - val_loss: 1.4123 - val_y1_output_loss: 0.3151 - val_y2_output_loss: 1.0650 - val_y1_output_root_mean_squared_error: 0.5610 - val_y2_output_root_mean_squared_error: 1.0477
# Epoch 480/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5751 - y1_output_loss: 0.1552 - y2_output_loss: 0.4260 - y1_output_root_mean_squared_error: 0.3948 - y2_output_root_mean_squared_error: 0.6475 - val_loss: 2.1858 - val_y1_output_loss: 0.1890 - val_y2_output_loss: 1.9446 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 1.4120
# Epoch 481/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.8744 - y1_output_loss: 0.1926 - y2_output_loss: 0.6760 - y1_output_root_mean_squared_error: 0.4405 - y2_output_root_mean_squared_error: 0.8248 - val_loss: 1.2369 - val_y1_output_loss: 0.2190 - val_y2_output_loss: 0.9876 - val_y1_output_root_mean_squared_error: 0.4700 - val_y2_output_root_mean_squared_error: 1.0080
# Epoch 482/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4604 - y1_output_loss: 0.1190 - y2_output_loss: 0.3388 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.5846 - val_loss: 1.0865 - val_y1_output_loss: 0.1705 - val_y2_output_loss: 0.8849 - val_y1_output_root_mean_squared_error: 0.4139 - val_y2_output_root_mean_squared_error: 0.9567
# Epoch 483/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5606 - y1_output_loss: 0.1301 - y2_output_loss: 0.4263 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.6556 - val_loss: 1.1101 - val_y1_output_loss: 0.2267 - val_y2_output_loss: 0.8471 - val_y1_output_root_mean_squared_error: 0.4835 - val_y2_output_root_mean_squared_error: 0.9361
# Epoch 484/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4664 - y1_output_loss: 0.1284 - y2_output_loss: 0.3350 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.5806 - val_loss: 1.0580 - val_y1_output_loss: 0.1727 - val_y2_output_loss: 0.8551 - val_y1_output_root_mean_squared_error: 0.4212 - val_y2_output_root_mean_squared_error: 0.9384
# Epoch 485/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.5001 - y1_output_loss: 0.1338 - y2_output_loss: 0.3689 - y1_output_root_mean_squared_error: 0.3609 - y2_output_root_mean_squared_error: 0.6081 - val_loss: 1.8707 - val_y1_output_loss: 0.3650 - val_y2_output_loss: 1.4537 - val_y1_output_root_mean_squared_error: 0.6140 - val_y2_output_root_mean_squared_error: 1.2222
# Epoch 486/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4908 - y1_output_loss: 0.1440 - y2_output_loss: 0.3455 - y1_output_root_mean_squared_error: 0.3786 - y2_output_root_mean_squared_error: 0.5894 - val_loss: 1.0631 - val_y1_output_loss: 0.1774 - val_y2_output_loss: 0.8551 - val_y1_output_root_mean_squared_error: 0.4253 - val_y2_output_root_mean_squared_error: 0.9393
# Epoch 487/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.5032 - y1_output_loss: 0.1249 - y2_output_loss: 0.3778 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.6151 - val_loss: 2.1307 - val_y1_output_loss: 0.3432 - val_y2_output_loss: 1.7348 - val_y1_output_root_mean_squared_error: 0.5885 - val_y2_output_root_mean_squared_error: 1.3358
# Epoch 488/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.9411 - y1_output_loss: 0.2003 - y2_output_loss: 0.7338 - y1_output_root_mean_squared_error: 0.4484 - y2_output_root_mean_squared_error: 0.8603 - val_loss: 1.3028 - val_y1_output_loss: 0.2907 - val_y2_output_loss: 0.9945 - val_y1_output_root_mean_squared_error: 0.5399 - val_y2_output_root_mean_squared_error: 1.0056
# Epoch 489/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4528 - y1_output_loss: 0.1267 - y2_output_loss: 0.3223 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5700 - val_loss: 1.1416 - val_y1_output_loss: 0.1635 - val_y2_output_loss: 0.9421 - val_y1_output_root_mean_squared_error: 0.4100 - val_y2_output_root_mean_squared_error: 0.9866
# Epoch 490/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4831 - y1_output_loss: 0.1259 - y2_output_loss: 0.3544 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5972 - val_loss: 1.1901 - val_y1_output_loss: 0.2540 - val_y2_output_loss: 0.9069 - val_y1_output_root_mean_squared_error: 0.5059 - val_y2_output_root_mean_squared_error: 0.9666
# Epoch 491/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.4343 - y1_output_loss: 0.1210 - y2_output_loss: 0.3099 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5589 - val_loss: 1.4056 - val_y1_output_loss: 0.1776 - val_y2_output_loss: 1.1840 - val_y1_output_root_mean_squared_error: 0.4257 - val_y2_output_root_mean_squared_error: 1.1065
# Epoch 492/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.4072 - y1_output_loss: 0.1196 - y2_output_loss: 0.2860 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5368 - val_loss: 1.1252 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 0.8601 - val_y1_output_root_mean_squared_error: 0.4842 - val_y2_output_root_mean_squared_error: 0.9438
# Epoch 493/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5620 - y1_output_loss: 0.1431 - y2_output_loss: 0.4184 - y1_output_root_mean_squared_error: 0.3755 - y2_output_root_mean_squared_error: 0.6488 - val_loss: 1.2322 - val_y1_output_loss: 0.2562 - val_y2_output_loss: 0.9442 - val_y1_output_root_mean_squared_error: 0.5072 - val_y2_output_root_mean_squared_error: 0.9874
# Epoch 494/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.4166 - y1_output_loss: 0.1259 - y2_output_loss: 0.2934 - y1_output_root_mean_squared_error: 0.3532 - y2_output_root_mean_squared_error: 0.5402 - val_loss: 1.4601 - val_y1_output_loss: 0.3923 - val_y2_output_loss: 1.0334 - val_y1_output_root_mean_squared_error: 0.6356 - val_y2_output_root_mean_squared_error: 1.0277
# Epoch 495/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4269 - y1_output_loss: 0.1355 - y2_output_loss: 0.2991 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.5486 - val_loss: 1.1242 - val_y1_output_loss: 0.2675 - val_y2_output_loss: 0.8403 - val_y1_output_root_mean_squared_error: 0.5150 - val_y2_output_root_mean_squared_error: 0.9268
# Epoch 496/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.3785 - y1_output_loss: 0.1107 - y2_output_loss: 0.2671 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.5178 - val_loss: 1.0758 - val_y1_output_loss: 0.2196 - val_y2_output_loss: 0.8436 - val_y1_output_root_mean_squared_error: 0.4587 - val_y2_output_root_mean_squared_error: 0.9303
# Epoch 497/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3770 - y1_output_loss: 0.1196 - y2_output_loss: 0.2558 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 1.0855 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.8697 - val_y1_output_root_mean_squared_error: 0.4312 - val_y2_output_root_mean_squared_error: 0.9484
# Epoch 498/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.6072 - y1_output_loss: 0.1491 - y2_output_loss: 0.4617 - y1_output_root_mean_squared_error: 0.3851 - y2_output_root_mean_squared_error: 0.6774 - val_loss: 1.0674 - val_y1_output_loss: 0.1997 - val_y2_output_loss: 0.8385 - val_y1_output_root_mean_squared_error: 0.4470 - val_y2_output_root_mean_squared_error: 0.9314
# Epoch 499/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4329 - y1_output_loss: 0.1297 - y2_output_loss: 0.3002 - y1_output_root_mean_squared_error: 0.3614 - y2_output_root_mean_squared_error: 0.5498 - val_loss: 1.1540 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.9104 - val_y1_output_root_mean_squared_error: 0.4596 - val_y2_output_root_mean_squared_error: 0.9709
# Epoch 500/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.6059 - y1_output_loss: 0.1475 - y2_output_loss: 0.4567 - y1_output_root_mean_squared_error: 0.3840 - y2_output_root_mean_squared_error: 0.6771 - val_loss: 1.2150 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 0.9830 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 1.0052

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 85us/sample - loss: 1.2150 - y1_output_loss: 0.2037 - y2_output_loss: 1.0023 - y1_output_root_mean_squared_error: 0.4523 - y2_output_root_mean_squared_error: 1.0052
# Loss = 1.2149960236115889, Y1_loss = 0.20373399555683136, Y1_mse = 0.4523352384567261, Y2_loss = 1.0023062229156494, Y2_mse = 1.0051809549331665

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
